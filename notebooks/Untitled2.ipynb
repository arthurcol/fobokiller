# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
import tensorflow
import pickle
import os
from fobokiller.cosim import compute_sim_df,summary_reviews,load_embedding

# %%
embedding = load_embedding()

# %%
result = compute_sim_df("i want the best burger",embedding,3000,10)

# %%
resul2 = summary_reviews(result,10)

# %%
resul2
# Out:
#                                                                       reviews  \
# alias
# blend-paris-27              {was a bit nervous in light of all the substan...
# il-etait-un-square-paris-6  {an excellent and friendly spot for burgers an...
# baāgaā-paris                {good burgers, good fries, friendly service. i...
# le-ruisseau-paris-2         {hands down the best burger i've ever had in p...
# shiso-burger-paris-2        {looking through yelp, this place popped up wh...
# burger-et-fils-paris        {so after living in europe for awhile i went p...
# big-fernand-paris-12        {i can't say this is the best burger i have ev...
# blend-paris-26              {"i still eat a burger at a counter with ketch...
# hank-paris-2                {whoa! you have to try this place! one of the ...
# pny-burger-oberkampf-paris  {no wonder it has the best reviews, pny close ...
#
#                             nb_sentences  nb_review  metric sim_ratio  \
# alias
# ...
