# %%
import pandas

sql = """
    SELECT *
    FROM `wagon-bootcamp-328013.trip.review`
    LIMIT 100
"""

# Run a Standard SQL query using the environment's default project
df = pandas.read_gbq(sql, dialect='standard')

# Run a Standard SQL query with the project set explicitly
project_id ="wagon-bootcamp-328013"
df = pandas.read_gbq(sql, project_id=project_id, dialect='standard')

# %%
df
# Out:
#                                                   nom  \
# 0    Restaurants du Monde - AUTOGRILL Carrousel du...
# 1                                  Rivoli Park Tavern
# 2                           Crep'eat Les Halles Paris
# 3                                  Aux Trois Maillets
# 4                                              Failed
# ..                                                ...
# 95                                         Pita tacos
# 96                                        Brousse Bar
# 97                                       Le Coq Heron
# 98                                       L incroyable
# 99                                       Ari’s Bagels
#
#                                                 liens   nb_avis  \
# 0   https://www.tripadvisor.fr/Restaurant_Review-g...  208 avis
# 1   https://www.tripadvisor.fr/Restaurant_Review-g...  154 avis
# 2   https://www.tripadvisor.fr/Restaurant_Review-g...   27 avis
# 3   https://www.tripadvisor.fr/Restaurant_Review-g...  207 avis
# 4   https://www.tripadvisor.fr/Restaurant_Review-g...  155 avis
# ..                                                ...       ...
# 95  https://www.tripadvisor.fr/Restaurant_Review-g...    5 avis
# 96  https://www.tripadvisor.fr/Restaurant_Review-g...    3 avis
# 97  https://www.tripadvisor.fr/Restaurant_Review-g...    1 avis
# 98  https://www.tripadvisor.fr/Restaurant_Review-g...   11 avis
# 99  https://www.tripadvisor.fr/Restaurant_Review-g...    5 avis
#
#                 type      prix
# 0             Ouvert  €€ - €€€
# 1             Ouvert    Failed
# 2             Ouvert    Failed
# 3     Française- Bar    Failed
# 4   Italienne- Pizza    Failed
# ..               ...       ...
# 95            Failed  €€ - €€€
# 96            Failed         €
# 97            Failed  €€ - €€€
# 98            Failed         €
# 99            Failed    Failed
#
# [100 rows x 5 columns]
